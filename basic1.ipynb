# %%
print("hello")
# Out:
# hello

# %%
x =5
y = True
print("value of x is :",x + x )
print(type(y))
# Out:
# value of x is : 10
# <class 'bool'>

# %%
y = "hello hbro"
print(y[0:6]+ y[6] + y[6].upper() + y[7:])
# Out:
# hello hHbro
